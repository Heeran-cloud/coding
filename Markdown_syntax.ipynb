# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>와우:</b> 신기하군.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>음:</b> 모지?
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Example:</b> 굿.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Tip:</b> 활용해야지.</div>

# %% [markdown]
# 글자를 크게 하면서, bold하게 하고 싶을때
# 1. Calamari
#     -

# %% [markdown]
# 글자를 bold하게 하고 싶을때
#
# __S__

# %% [markdown]
# 사진 위치,사이즈 조절 하고 싶을때
# <img width='70%' src='./참조/clova_ocr.png' align='right'>
#
#
# <img width='70%' src='./참조/clova_ocr.png' align='left'>
#
#
# <img width='70%' src='./참조/clova_ocr.png'>

# %% [markdown]
# 글자 안으로 들여쓰기 하고 싶을때
#
# ```
# 안녕하세요.
# ```
